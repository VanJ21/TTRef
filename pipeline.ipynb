# %%
# find YOLO Bounding Boxes in a video
import ultralytics
import cv2

# Load the model
model = ultralytics.YOLO('weights/yolo8nTablePlayer.pt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 6
#       3 import cv2
#       5 # Load the model
# ----> 6 model = ultralytics.YOLO('weights/yolo8nTablePlayer.pt')
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/models/yolo/model.py:23, in YOLO.__init__(self, model, task, verbose)
#      20     self.__dict__ = new_instance.__dict__
#      21 else:
#      22     # Continue with default YOLO initialization
# ---> 23     super().__init__(model=model, task=task, verbose=verbose)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:152, in Model.__init__(self, model, task, verbose)
#     150     self._new(model, task=task, verbose=verbose)
#     151 else:
# --> 152     self._load(model, task=task)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/engine/model.py:241, in Model._load(self, weights, task)
#     238 weights = checks.check_model_file_from_stem(weights)  # add suffix, i.e. yolov8n -> yolov8n.pt
#     240 if Path(weights).suffix == ".pt":
# --> 241     self.model, self.ckpt = attempt_load_one_weight(weights)
#     242     self.task = self.model.args["task"]
#     243     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:806, in attempt_load_one_weight(weight, device, inplace, fuse)
#     804 def attempt_load_one_weight(weight, device=None, inplace=True, fuse=False):
#     805     """Loads a single model weights."""
# --> 806     ckpt, weight = torch_safe_load(weight)  # load ckpt
#     807     args = {**DEFAULT_CFG_DICT, **(ckpt.get("train_args", {}))}  # combine model and default args, preferring model args
#     808     model = (ckpt.get("ema") or ckpt["model"]).to(device).float()  # FP32 model
#
# File /opt/anaconda3/lib/python3.11/site-packages/ultralytics/nn/tasks.py:732, in torch_safe_load(weight)
#     724 try:
#     725     with temporary_modules(
#     726         {
#     727             "ultralytics.yolo.utils": "ultralytics.utils",
#    (...)
#     730         }
#     731     ):  # for legacy 8.0 Classify and Pose models
# --> 732         ckpt = torch.load(file, map_location="cpu")
#     734 except ModuleNotFoundError as e:  # e.name is missing module name
#     735     if e.name == "models":
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:791, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     788 if 'encoding' not in pickle_load_args.keys():
#     789     pickle_load_args['encoding'] = 'utf-8'
# --> 791 with _open_file_like(f, 'rb') as opened_file:
#     792     if _is_zipfile(opened_file):
#     793         # The zipfile reader is going to advance the current file position.
#     794         # If we want to actually tail call to torch.jit.load, we need to
#     795         # reset back to the original position.
#     796         orig_position = opened_file.tell()
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:271, in _open_file_like(name_or_buffer, mode)
#     269 def _open_file_like(name_or_buffer, mode):
#     270     if _is_path(name_or_buffer):
# --> 271         return _open_file(name_or_buffer, mode)
#     272     else:
#     273         if 'w' in mode:
#
# File /opt/anaconda3/lib/python3.11/site-packages/torch/serialization.py:252, in _open_file.__init__(self, name, mode)
#     251 def __init__(self, name, mode):
# --> 252     super().__init__(open(name, mode))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'weights/yolo8nTablePlayer.pt'

# %%
import cv2
import json

def process_video_with_bboxes(video_path, model, output_video_path='output_video.mp4', bbox_output_path='bboxes.json'):
    cap = cv2.VideoCapture(video_path)

    # Check if the video opened successfully
    if not cap.isOpened():
        print("Error: Could not open video.")
        return

    # Get video properties
    frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))

    # Initialize video writer
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec
    out = cv2.VideoWriter(output_video_path, fourcc, fps, (frame_width, frame_height))

    # Get class names from the model
    class_names = model.names

    # To store bounding box data
    bbox_data = []

    # Loop through the video frames
    frame_id = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Perform inference on the frame
        results = model(frame)

        frame_bboxes = []

        # Extract bounding boxes and labels if there are any detections
        if len(results) > 0 and results[0].boxes is not None:
            bboxes = results[0].boxes.xyxy.cpu().numpy()  # x1, y1, x2, y2, confidence, class
            classes = results[0].boxes.cls.cpu().numpy()  # class IDs
            confidences = results[0].boxes.conf.cpu().numpy()  # confidences

            # Draw bounding boxes and labels on the frame
            for bbox, cls, conf in zip(bboxes, classes, confidences):
                x1, y1, x2, y2 = map(int, bbox[:4])
                label = f"{class_names[int(cls)]} {conf:.2f}"

                # Draw rectangle
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                # Put label text above the rectangle
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (36, 255, 12), 2)

                # Save bounding box data
                frame_bboxes.append({
                    'frame_id': frame_id,
                    'class': class_names[int(cls)],
                    'confidence': float(conf),
                    'bbox': [x1, y1, x2, y2]
                })

        # Append frame bounding boxes to bbox data
        if frame_bboxes:
            bbox_data.append(frame_bboxes)

        # Write the frame to the output video
        out.write(frame)

        # Display the frame with bounding boxes
        cv2.imshow('Frame', frame)

        # Break the loop if 'q' is pressed (commented out for Colab)
        # if cv2.waitKey(1) & 0xFF == ord('q'):
        #    break

        frame_id += 1

    # Release the video capture and writer objects
    cap.release()
    out.release()
    cv2.destroyAllWindows()

    # Save bounding box data to a file
    with open(bbox_output_path, 'w') as f:
        json.dump(bbox_data, f, indent=4)

    print("Video saved to:", output_video_path)
    print("Bounding box data saved to:", bbox_output_path)

# %%
video_path = 'videos/uncut/MLTT.mp4'
process_video_with_bboxes(video_path, model, 'out/videos/MLTT_uncut_with_bboxes.mp4', 'out/data/MLTT_uncut_bbox.json')
# Out:
# 0: 384x640 1 table, 445.3ms
# Speed: 3.8ms preprocess, 445.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 436.1ms
# Speed: 1.2ms preprocess, 436.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 433.6ms
# Speed: 1.4ms preprocess, 433.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 425.8ms
# Speed: 1.3ms preprocess, 425.8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 428.2ms
# Speed: 1.4ms preprocess, 428.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 428.5ms
# Speed: 1.1ms preprocess, 428.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 432.6ms
# Speed: 1.9ms preprocess, 432.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 422.6ms
# Speed: 1.2ms preprocess, 422.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 433.2ms
# Speed: 1.4ms preprocess, 433.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 428.5ms
# Speed: 1.1ms preprocess, 428.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 438.6ms
# Speed: 1.2ms preprocess, 438.6ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 434.2ms
# Speed: 1.9ms preprocess, 434.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 419.7ms
# Speed: 1.3ms preprocess, 419.7ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 440.4ms
# Speed: 1.3ms preprocess, 440.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 419.7ms
# Speed: 1.3ms preprocess, 419.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 418.5ms
# Speed: 1.3ms preprocess, 418.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 415.9ms
# Speed: 2.8ms preprocess, 415.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 480.0ms
# Speed: 1.3ms preprocess, 480.0ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 445.7ms
# Speed: 1.5ms preprocess, 445.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 422.9ms
# Speed: 1.8ms preprocess, 422.9ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tables, 418.4ms
# Speed: 1.0ms preprocess, 418.4ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 428.5ms
# Speed: 1.3ms preprocess, 428.5ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table, 425.9ms
# Speed: 2.1ms preprocess, 425.9ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 table,